# %%
# !pip install bs4
# !pip install requests

# %%
import requests
from bs4 import BeautifulSoup as soup

# %%
def get_content_string(url):
  page = requests.get(url)
  page_soup = soup(page.content, 'html.parser')
  print(page_soup)

  containers = page_soup.find_all('script', {'type' : "p class 'p1'"})

  articles = []
  for container in containers:
      articles.append(container)
  print(articles)

# %%
get_content_string('https://www.diariocolatino.com/')
# Out:
# <!DOCTYPE html>
#
# <html lang="es" prefix="og: http://ogp.me/ns#">
# <head>
# <title>Diario Co Latino - Informándote con Credibilidad</title>
# <meta content="cj5lwqWqNYqXnYoP-mVGsOKdhXPfZMTkWIGVCEs0PWY" name="google-site-verification"/>
# <meta charset="utf-8"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.diariocolatino.com/xmlrpc.php" rel="pingback"/>
# <script>(function(d, s, id){
# 				 var js, fjs = d.getElementsByTagName(s)[0];
# 				 if (d.getElementById(id)) {return;}
# 				 js = d.createElement(s); js.id = id;
# 				 js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.6";
# 				 fjs.parentNode.insertBefore(js, fjs);
# 			   }(document, 'script', 'facebook-jssdk'));</script><meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <title>Home - Diario Co Latino</title>
# <link href="https://www.diariocolatino.com/" rel="canonical"/>
# ...
