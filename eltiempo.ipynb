# %%
# !pip3 install newspaper3k
import requests
import nltk
nltk.download('punkt')
from bs4 import BeautifulSoup
from newspaper import Article
# Out:
# Requirement already satisfied: newspaper3k in /root/venv/lib/python3.7/site-packages (0.2.8)
# Requirement already satisfied: feedparser>=5.2.1 in /root/venv/lib/python3.7/site-packages (from newspaper3k) (6.0.8)
# Requirement already satisfied: tldextract>=2.0.1 in /root/venv/lib/python3.7/site-packages (from newspaper3k) (3.1.2)
# Requirement already satisfied: jieba3k>=0.35.1 in /root/venv/lib/python3.7/site-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: feedfinder2>=0.0.4 in /root/venv/lib/python3.7/site-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: Pillow>=3.3.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from newspaper3k) (9.0.1)
# Requirement already satisfied: requests>=2.10.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from newspaper3k) (2.27.1)
# Requirement already satisfied: lxml>=3.6.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from newspaper3k) (4.7.1)
# Requirement already satisfied: cssselect>=0.9.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from newspaper3k) (1.1.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /root/venv/lib/python3.7/site-packages (from newspaper3k) (4.10.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from newspaper3k) (2.8.2)
# Requirement already satisfied: nltk>=3.2.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from newspaper3k) (3.7)
# Requirement already satisfied: tinysegmenter==0.3 in /root/venv/lib/python3.7/site-packages (from newspaper3k) (0.3)
# Requirement already satisfied: PyYAML>=3.11 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from newspaper3k) (6.0)
# Requirement already satisfied: sgmllib3k in /root/venv/lib/python3.7/site-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: idna in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from tldextract>=2.0.1->newspaper3k) (3.3)
# Requirement already satisfied: filelock>=3.0.8 in /root/venv/lib/python3.7/site-packages (from tldextract>=2.0.1->newspaper3k) (3.5.0)
# Requirement already satisfied: requests-file>=1.4 in /root/venv/lib/python3.7/site-packages (from tldextract>=2.0.1->newspaper3k) (1.5.1)
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests>=2.10.0->newspaper3k) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests>=2.10.0->newspaper3k) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests>=2.10.0->newspaper3k) (2.0.12)
# Requirement already satisfied: soupsieve>1.2 in /root/venv/lib/python3.7/site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.3.1)
# Requirement already satisfied: joblib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nltk>=3.2.1->newspaper3k) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nltk>=3.2.1->newspaper3k) (2022.1.18)
# Requirement already satisfied: tqdm in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nltk>=3.2.1->newspaper3k) (4.62.3)
# Requirement already satisfied: click in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nltk>=3.2.1->newspaper3k) (8.0.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from click->nltk>=3.2.1->newspaper3k) (4.11.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->click->nltk>=3.2.1->newspaper3k) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->click->nltk>=3.2.1->newspaper3k) (3.7.0)
# WARNING: You are using pip version 20.1.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
feed = 'https://www.eltiempo.com/rss/politica.xml'

response = requests.get(feed)

website = response.content

soup = BeautifulSoup(website, features='xml')

items = soup.find_all('item')

articles = []
for item in items:
    link = item.find('link').text
    articles.append(link)

# %%
from newspaper import Article

# %%
for url in articles:
    article = Article(url)
    article.download()
    article.parse()
    article.nlp()

    title = article.title
    text = article.text
    keywords = article.keywords
    summary = article.summary
    date = article.publish_date
    authors = article.authors

        
    print('************************************************************')
    print(f"Title: {title}")
    print(f"URL: {url}")
    print(f"Authors: {authors}")
    print(f"Date: {date}")
    print(f"Keywords: {keywords}")
    print(f"Summary: {summary}")
    print(f"Text: {text}")
    print('************************************************************')
# Out:
# ************************************************************
# Title: Ingrid Betancourt dice que se expresó mal en polémica frase sobre mujeres
# URL: https://www.eltiempo.com/elecciones-2022/candidatos/ingrid-betancourt-arma-polemica-con-frase-de-abuso-sexual-651836
# Authors: ['Casa Editorial El Tiempo']
# Date: 2022-02-15 00:00:00
# Keywords: ['sobre', 'las', 'su', 'y', 'ingrid', 'se', 'el', 'expresó', 'mujeres', 'mujer', 'mal', 'frase', 'la', 'que', 'en', 'polémica']
# Summary: Ingrid Betancourt, aspirante a la presidencia de la República, armó una polémica al afirmar que hay "mujeres que se hacen violar" en su respuesta durante un debate presidencial.
# Muchas veces nos damos cuenta, sobre todo en los barrios más populares, que las mujeres que se hacen violar, se hacen violar por gente muy cercana a la familia.
# La aspirante presidencial por el partido Verde Oxígeno hizo la afirmación en un debate que se realizó en la mañana de este martes en la Universidad Sergio Arboleda.
# "Que 'las mujeres se hacen violar' dijo Ingrid Betancourt.
# "Obviamente que no (quiso decir que las mujeres se hacen violar) y me excuso y fue una embarrada", expresó.
# Text: Ingrid Betancourt, aspirante a la presidencia de la República, armó una polémica al afirmar que hay "mujeres que se hacen violar" en su respuesta durante un debate presidencial.
#
#
#
# (Puede leer: Duque comparece ante el Parlamento Europeo)
#
#
#
# “Es un tema sobre la mujer que nos preocupa a todos. Yo enfocaría la solución en prevención. Muchas veces nos damos cuenta, sobre todo en los barrios más populares, que las mujeres que se hacen violar, se hacen violar por gente muy cercana a la familia. O se hacen seguir por delincuentes que siguen su ruta, saben por dónde van a pasar y son depredadores que las están persiguiendo y ellas están totalmente desprotegidas”, dijo.
#
# La aspirante presidencial por el partido Verde Oxígeno hizo la afirmación en un debate que se realizó en la mañana de este martes en la Universidad Sergio Arboleda. En el encuentro también participaron Óscar Iván Zuluaga, David Barguil, Camilo Romero, Jorge Enrique Robledo y Enrique Gómez.
#
#
#
# "Sentí que había una incomodidad cuando estaba expresando esto, obviamente quería decir que las mujeres cuando están en este espacio son víctimas. Esto no quiere decir que ellas lo busquen", aclaró posteriormente la candidata en el mismo escenario.
#
#
#
# La pregunta realizada a los candidatos decía: "En Colombia el 86% de exámenes médicos legales son por presunto delito sexual hacia niñas y mujeres. ¿Cómo desde la presidencia usted promovería acciones positivas para el cuidado, protección y garantía de la integridad y de la seguridad a las mujeres y a las niñas?".
#
#
#
# (Lea también: Revocan candidatura presidencial de John Milton Rodríguez)
#
#
#
# Luego la candidata complementó su respuesta y señaló sus propuestas en esta materia: “Yo veo dos sitios donde podemos actuar. Uno, los colegios. El colegio tiene que ser un centro de protección para la mujer y la niña".
#
#
#
# Y agregó: "Yo desde la presidencia quiero construir un centro para la mujer donde pueda protegerse, donde tenga apoyo psicológico, apoyo para tomar decisiones de vida sobre su sexualidad, apoyo si queda embarazada, apoyo si quiere dar en adopción a su hijo. Apoyo si quiere tener su niño y tiene dificultades económicas. Apoyo total para la mujer en Colombia”.
#
#
#
# Su primera respuesta ha generado gran rechazo en las mujeres porque su justificación inicial pone la culpa y la responsabilidad de la violación sobre la mujer y no sobre los hombres que violentan el cuerpo de una mujer. En estos casos es la mujer la víctima de los hechos y, por lo tanto, es el victimario quien tiene la responsabilidad de sus actos.
#
# "Que 'las mujeres se hacen violar' dijo Ingrid Betancourt. ¿Cuál será entonces su propuesta para erradicar la violencia de género si según ella son las mismas mujeres las responsables de esta violencia?", escribió la analista Sara Tufano.
#
#
#
# A la salida del debate la aspirante a la Casa de Nariño respondió a la prensa sobre su polémica frase: "embarrada. Tengo dos idiomas en la cabeza e hice corto circuito. No volverá a suceder".
#
#
#
# Aclaró que "las mujeres que están en situación de pobreza son las primeras víctimas de las agresiones sexuales porque cuando ellas se desplazan muchas veces ahí las violan. Además muchas veces las violaciones son intrafamiliares. Desgraciadamente la mujer está desprotegida".
#
#
#
# "Obviamente que no (quiso decir que las mujeres se hacen violar) y me excuso y fue una embarrada", expresó.
#
# POLÍTICA
#
# En otras noticias
#
# - Duque se refirió de nuevo a los señalamientos de Aida Merlano
#
#
#
# - ‘No podemos estar hablando en este momento de guerras’: Duque sobre Ucrania
# ************************************************************
# ************************************************************
# Title: Revocan candidatura presidencial de John Milton Rodríguez
# URL: https://www.eltiempo.com/politica/partidos-politicos/revocan-candidatura-presidencial-de-john-milton-rodriguez-651856
# Authors: ['Casa Editorial El Tiempo']
# Date: 2022-02-15 00:00:00
# Keywords: ['milton', 'john', 'revocan', 'candidatura', 'presidencial', 'rodríguez']
# Summary:
# Text:
# ************************************************************
# ************************************************************
# Title: Duque advierte sobre posible intervención de 'hackers' en las elecciones
# URL: https://www.eltiempo.com/politica/gobierno/ivan-duque-asegura-que-hackers-pretenden-interferir-en-elecciones-651861
# Authors: ['Casa Editorial El Tiempo']
# Date: 2022-02-15 00:00:00
# Keywords: ['sobre', 'duque', 'advierte', 'hackers', 'posible', 'en', 'las', 'elecciones', 'intervención']
# Summary:
# Text:
# ************************************************************
# ************************************************************
# Title: 'Santos ignoró informe sobre Raúl Reyes para complacer a Chávez': Uribe
# URL: https://www.eltiempo.com/politica/partidos-politicos/uribe-acusa-a-santos-de-ignorar-informe-sobre-computadores-de-raul-reyes-651817
# Authors: ['Casa Editorial El Tiempo']
# Date: 2022-02-15 00:00:00
# Keywords: ['sobre', 'uribe', 'para', 'reyes', 'ignoró', 'santos', 'complacer', 'raúl', 'informe', 'chávez']
# Summary:
# Text:
# ************************************************************
# ************************************************************
# Title: ¿Quién es Paola Ochoa, la fórmula vicepresidencial de Rodolfo Hernández?
# URL: https://www.eltiempo.com/elecciones-2022/presidencia/quien-es-paola-ochoa-la-formula-vicepresidencial-de-rodolfo-hernandez-651660
# Authors: ['Casa Editorial El Tiempo']
# Date: 2022-02-14 00:00:00
# Keywords: ['ochoa', 'vicepresidencial', 'paola', 'es', 'quién', 'rodolfo', 'la', 'hernández', 'fórmula']
# Summary:
# Text:
# ************************************************************
# ************************************************************
# Title: Jurados de votación 2022: ¿Cómo saber si lo eligieron? Aquí le explicamos
# URL: https://www.eltiempo.com/elecciones-2022/actualidad-electoral/jurados-de-votacion-consulte-si-es-jurado-y-como-los-eligen-650932
# Authors: ['Casa Editorial El Tiempo']
# Date: 2022-02-11 00:00:00
# Keywords: ['eligieron', 'votación', 'cómo', 'las', 'los', 'y', 'aquí', 'saber', 'explicamos', 'el', 'jurados', 'se', 'le', 'la', 'si', 'que', 'en', 'lo']
# Summary: Se acercan las elecciones al Congreso y a la Presidencia, que se desarrollaran el 13 de marzo y el 29 de mayo respectivamente.
# Aquí respondemos algunas preguntas frecuentes sobre los jurados de votación.
# De acuerdo con la Registraduría, los jurados de votación son parte de la sociedad civil y colaboran como 'servidores públicos' durante los comicios.
# Facebook Twitter LinkedinSi usted es jurado de votación en las elecciones al Congreso, no necesariamente será jurado en las presidenciales.
# Luego, el vicepresidente registra a cada elector en el formulario E-11 y el vocal entrega el tarjetón.
# Text: Se acercan las elecciones al Congreso y a la Presidencia, que se desarrollaran el 13 de marzo y el 29 de mayo respectivamente. Un evento importante que definirá el rumbo del país para los próximos cuatro años.
#
# Ese día, todos los colombianos saldrán a votar, pero una parte de ellos, también deberá ser jurado de votación, un 'cargo' fundamental para velar por la transparencia del proceso electoral. Son ellos quienes se encargan de ayudar a los sufragantes y hacer el conteo de los votos.
#
# En pocas palabras, de los jurados de votación depende gran parte del avance de los comicios, pues en sus manos está todo el material de las elecciones: el listado de las cédulas inscritas, el formulario de las personas que votaron, los tarjetones y los certificados de votación, pero, además, vigilan las urnas y garantizan el éxito de la jornada.
#
#
#
# (Lea también: Aliado de Gaviria anuncia demanda penal contra Ingrid).
#
#
#
# Aquí respondemos algunas preguntas frecuentes sobre los jurados de votación.
#
# Facebook Twitter Linkedin
#
# Los jurados garantizan la transparencia de la jornada electoral. Foto: EFE
#
# ¿Cómo se eligen los jurados de votación?
#
# De acuerdo con la Registraduría, los jurados de votación son parte de la sociedad civil y colaboran como 'servidores públicos' durante los comicios. Ellos son elegidos con ayuda de un software que los escoge al azar, entre la base de datos de la institución.
#
#
#
# La información se nutre de los listados que entregan las empresas privadas, las instituciones educativas y los partidos y movimientos políticos.
#
#
#
# (De interés: ‘Los uribistas deberíamos votar en las consultas’: María Fernanda Cabal).
#
# ¿Qué hace un jurado de votación?
#
# Cabe recordar que siempre hay seis jurados de votación por cada mesa, entre ellos, hay un presidente, vicepresidente y vocal.
#
# Facebook Twitter Linkedin
#
# Si usted es jurado de votación en las elecciones al Congreso, no necesariamente será jurado en las presidenciales. Foto: Rodolfo González
#
# El presidente es quien debe recibir el documento de identidad de los votantes y lo verifica en el formulario E-10, es decir, la lista de sufragantes. Luego, el vicepresidente registra a cada elector en el formulario E-11 y el vocal entrega el tarjetón.
#
#
#
# Los otros jurados, por su parte, son suplentes y deben vigilar la urna, ayudar al sufragante cuando lo necesita, y entregar el certificado electoral.
#
#
#
# (Le recomendamos: Katherine Miranda responde ante acusaciones de plagio en video de campaña).
#
#
#
# Al finalizar la jornada, se encargan de contar los votos, destruir los tarjetones y el material electoral que sobró y organizar el puesto según las indicaciones del personal de la Registraduría.
#
#
#
# Aunque el horario de las votaciones es de ocho de la mañana a cuatro de la tarde, los jurados deberán llegar antes, para organizar la mesa de votación, y salir después, para realizar el conteo de los sufragios.
#
# ¿Qué significa ser jurado de votación remanente?
#
# Se trata de las personas que son seleccionadas para sustituir a los jurados que, por algún motivo de fuerza mayor, no se presentan a ejercer su cargo. De hecho, a diferencia de un jurado, no son asignados a una mesa específica, pues solo se desempeñarán como uno si falta alguien.
#
#
#
# (Puede leer: ¿Qué hay tras el pulso entre Gustavo Petro y Alejandro Char?).
#
#
#
# El personal de la Registraduría es quien se encarga de asignar un remanente a una mesa de votación, en caso de ser necesario.
#
# Facebook Twitter Linkedin
#
# No cumplir con el servicio como jurado de votación le ocasionará sanciones. Foto: Guillermo González. Archivo EL TIEMPO
#
# ¿Cómo saber si soy jurado de votación?
#
# Tenga en cuenta que para las elecciones del Congreso, la Registraduría dará a conocer a los seleccionados, a partir del 13 de febrero, en listados publicados en sus sedes y las alcaldías, por ejemplo, en Bogotá, se pueden ver los documentos en la Alcaldía Mayor.
#
#
#
# Pero, además, usted puede consultar si es jurado de votación a través de la página de la Registraduría, la aplicación Infovotantes o con las oficinas de Talento Humano de su empresa o universidad.
#
#
#
# (Además: Rodolfo Hernández les pidió disculpas a Dilian Francisca Toro y a su esposo).
#
# Facebook Twitter Linkedin
#
# Los jurados reciben un día de compensatorio remunerado. Foto: Rodrigo Sepúlveda. EL TIEMPO
#
# Sin embargo, de ser uno de los elegidos, le deberá llegar una notificación a su celular o correo electrónico. Aún así, si no le llega, lo mejor es revisar en los canales ya explicados, pues el no ser alertado no lo exonera de prestar el servicio.
#
# ¿Si me asignan un puesto de votación lejos de mi casa puedo pedir cambio?
#
# Debido a que hay puestos de votación alejados de zonas residenciales, es probable que le sea asignado un lugar lejos de su hogar, pero no puede solicitar cambio. Además, esta situación tampoco lo exonera de no ser jurado de votación.
#
#
#
# (Siga leyendo: La respuesta de Alejandro Gaviria al comentario de María Fernanda Cabal).
#
#
#
# Por ejemplo, si su empleador o institución educativa informó la dirección donde usted labora o estudia, en lugar de la de su residencia, la Registraduría entiende que usted está en capacidad de trasladarse hasta el lugar de votación asignado.
#
# Más noticias
#
# La explicación de Zuluaga para insultar al alcalde de Cali
#
#
#
# Coalición Centro Esperanza exige renuncia de Álex Char
#
#
#
# Nueva encuesta: Gustavo Petro y Rodolfo Hernández crecen
#
#
#
# Tendencias EL TIEMPO
# ************************************************************
# ************************************************************
# Title: Duque comparece ante el Parlamento Europeo
# URL: https://www.eltiempo.com/politica/gobierno/duque-comparece-ante-el-parlamento-europeo-651752
# Authors: ['Casa Editorial El Tiempo']
# Date: 2022-02-15 00:00:00
# Keywords: ['duque', 'europeo', 'parlamento', 'el', 'comparece', 'ante']
# Summary:
# Text:
# ************************************************************
# ************************************************************
# Title: En vivo: Iván Duque habla ante el Parlamento Europeo
# URL: https://www.eltiempo.com/politica/gobierno/en-vivo-ivan-duque-habla-al-parlamento-europeo-651751
# Authors: ['Casa Editorial El Tiempo']
# Date: 2022-02-15 00:00:00
# Keywords: ['duque', 'europeo', 'parlamento', 'iván', 'el', 'vivo', 'ante', 'en', 'habla']
# Summary:
# Text:
# ************************************************************
# ************************************************************
# Title: ¿Por qué los políticos buscan periodistas como sus compañeros de fórmula?
# URL: https://www.eltiempo.com/politica/partidos-politicos/elecciones-2022-por-que-buscan-a-periodistas-para-formula-vicepresidencial-651661
# Authors: ['Casa Editorial El Tiempo']
# Date: 2022-02-14 00:00:00
# Keywords: ['compañeros', 'por', 'los', 'su', 'es', 'se', 'sus', 'el', 'qué', 'como', 'la', 'rodolfo', 'periodistas', 'políticos', 'buscan', 'en', 'que', 'fórmula']
# Summary: Con la designación de Paola Ochoa como fórmula vicepresidencial de Rodolfo Hernández son ya varios los periodistas que terminan como compañeros de campaña de políticos.
# )También puede leer: Periodista Paola Ochoa será fórmula vicepresidencial de Rodolfo Hernández)Hay que recordar que Álvaro Uribe tuvo como su fórmula a Francisco Santos, quien venía de ser periodista de EL TIEMPO.
# Actualmente el Nuevo Liberalismo tiene como su cabeza de lista del Senado a la periodista Mabel Lara.
# Pero a qué se debe esto, porque algunos sectores políticos les apuestan a los periodistas para tenerlos como sus fórmulas o para que hagan parte de sus listas.
# El representante a la Cámara Inti Asprilla (Pacto Histórico) dijo que con Paola Ochoa como su fórmula a la vicepresidencia, se entiende porque se dice que Rodolfo Hernández es como un Donald Trump criollo.
# Text: Con la designación de Paola Ochoa como fórmula vicepresidencial de Rodolfo Hernández son ya varios los periodistas que terminan como compañeros de campaña de políticos.
#
#
#
# )También puede leer: Periodista Paola Ochoa será fórmula vicepresidencial de Rodolfo Hernández)
#
#
#
# Hay que recordar que Álvaro Uribe tuvo como su fórmula a Francisco Santos, quien venía de ser periodista de EL TIEMPO. Y durante los dos periodos que Uribe fue jefe de Estado, lo mantuvo en esa dignidad.
#
#
#
# (No deje de leer: ¿Quién es Paola Ochoa, la fórmula vicepresidencial de Rodolfo Hérnandez?)
#
# Al no poder aspirar a la reelección presidencial por segunda ocasión, el guiño de Uribe recayó en Juan Manuel Santos, quien también se había desempeñado como periodista de EL TIEMPO.
#
#
#
# (No deje de leer: Debemos garantizar ‘una elección libre de amenazas’, dice la ‘Vice’)
#
#
#
# Pero no han sido sólo para los casos de la presidencia sino también hay que recordar los casos de otros periodistas o comunicadores que han estado en listas al Congreso y que incluso han llegado a tener su curul en el Capitolio.
#
#
#
# En este punto se pueden mencionar los nombres del narrador deportivo Edgar Perea, quien fue congresista, al igual que Alfonso Lizarazo, quien dirigió el programa Sábados felices durante 26 años.
#
#
#
# (También lea: Duque y la OTAN hablan de apoyo ruso al 'régimen represivo' de Venezuela)
#
#
#
# A esto se debe sumar que Gustavo Petro tuvo al periodista Hollman Morris en su lista al Concejo de Bogotá.
#
#
#
# Más recientemente hay que recordar que Carlos Fernando Galán tuvo en su lista para el Concejo de Bogotá a Marisol Gómez Giraldo, quien se había desempeñado como periodista de EL TIEMPO.
#
#
#
# Actualmente el Nuevo Liberalismo tiene como su cabeza de lista del Senado a la periodista Mabel Lara.
#
#
#
# Pero a qué se debe esto, porque algunos sectores políticos les apuestan a los periodistas para tenerlos como sus fórmulas o para que hagan parte de sus listas.
#
# En el caso de Rodolfo Hernández, que no es muy conocido, es una tentativa de buscar un acercamiento a los medios más tradicionales FACEBOOK
#
# TWITTER
#
# Carlos Arias, profesor de la universidad Externado, dijo que la única razón por las que se hacen estas designaciones es porque les permite “tener una ventana mediática que no tienen”.
#
#
#
# La idea es que al tener al comunicador, esa figura les ayuda a potenciar su mensaje en la medida que conocen los medios, saben quiénes trabajan allí, qué es lo que quieren y qué es lo que necesitan.
#
#
#
# De acuerdo con Arias, esas designaciones les permiten a los candidatos tener un contexto mucho más real sobre cómo los están viendo los periodistas y les ayudan a entender las narrativas, cuáles son los mensajes que debe mandar y cómo funcionan los medios para generar agenda.
#
#
#
# El representante a la Cámara Inti Asprilla (Pacto Histórico) dijo que con Paola Ochoa como su fórmula a la vicepresidencia, se entiende porque se dice que Rodolfo Hernández es como un Donald Trump criollo.
#
#
#
# Yann Basset, profesor de la universidad del Rosario, dijo que los candidatos están tratando de llevarse bien con los medios de comunicación hasta el punto de que a veces les dan una importancia excesiva.
#
#
#
# "En el caso de Rodolfo Hernández, que no es muy conocido, es una tentativa de buscar un acercamiento a los medios más tradicionales para cubrir esa parte que le falta en su campaña", dijo Basset.
#
#
#
# Le puede interesar: ‘La felicito por ser la fórmula de Rodolfo’: Angélica Lozano a Paola Ochoa
# ************************************************************
# ************************************************************
# Title: Registraduría recibe denuncias por condicionar renovación de contratos
# URL: https://www.eltiempo.com/politica/gobierno/registraduria-que-responde-ante-denuncias-por-contrataciones-651681
# Authors: ['Casa Editorial El Tiempo']
# Date: 2022-02-14 00:00:00
# Keywords: ['por', 'recibe', 'renovación', 'condicionar', 'contratos', 'denuncias', 'registraduría']
# Summary:
# Text:
# ************************************************************

# %%
len(articles)
# Out:
# 10

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=24c8dfa6-c0e9-4b84-90c4-b37d7d82c67d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
