# %%
# !pip install pycaret[full] --quiet
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# tensorflow 2.8.0 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.12.1 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.32.0 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# arviz 0.11.4 requires typing-extensions<4,>=3.7.4.3, but you have typing-extensions 4.1.1 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.

# %%
pip install --upgrade numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.19.5)
# Collecting numpy
#   Using cached numpy-1.21.5-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.21.5 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.12.1 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.32.0 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# arviz 0.11.4 requires typing-extensions<4,>=3.7.4.3, but you have typing-extensions 4.1.1 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed numpy-1.21.5

# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_parquet('/content/16eac85914e04a167f656392c2850aac197133366a5d953a9499702e5360d7a4')

# %%
test = pd.read_parquet('/content/df1dafd7a13176813587af8ca6367f723827be4a93522907e443925340f4e445')

# %%
train.head()
# Out:
#   Annotation_action  Article_ID Author  \
# 0    Don't Annotate        2858   None
# 1    Don't Annotate        2005   None
# 2          Annotate         453   None
# 3    Don't Annotate         590   None
# 4    Don't Annotate        1008   None
#
#                                              Content Corrected_label  \
# 0  En un artículo difundido en su sitio personal ...            Fake
# 1  🔴 El líder nacional de Morena, @mario_delgado ...            True
# 2  NUEVA YORK.- Ben Simmons aseguró el martes qu...            Fake
# 3  Un estudio realizado por la empresa tecnológi...            True
# 4  \nLa Subcomisión Política leyó ayer públic...            True
#
#   Date_posted                                               Link Prediction  \
# 0  2022-03-01                                               None       Fake
# 1  2022-01-19                                               None       True
# 2        None  https://vanguardia.com.mx/deportes/ben-simmons...       Fake
# 3        None  http://www.elnuevosiglo.com.co/articulos/02-14...       Fake
# 4  2020-07-28  https://diario.elmundo.sv/Política/subcomision...       True
#
#    Prediction_prob                                  Preprocessed_text  \
# 0         0.632735  artículo difundido sitio personal coordinador...
# 1         0.441359  líder nacional Morena @mario_delgado llamar I...
# 2         0.564037  YORK.- Ben Simmons martes problema mental inic...
# 3         0.584732  estudio empresa tecnológico gamificación Nawai...
# 4         0.357733  Subcomisión Política leer públicamente informe...
#
#    Rescaled_prediction_prob          Source  \
# 0                  0.132735         proceso
# 1                  0.058641       Excelsior
# 2                  0.064037   La Vanguardia
# 3                  0.084732  El Nuevo Siglo
# 4                  0.142267        El Mundo
#
#                                                 Text  \
# 0  Source:proceso\n\n Prediction:Fake\n\n Content...
# 1  Source:Excelsior\n\n Prediction:True\n\n Conte...
# 2  Source:La Vanguardia\n\n Prediction:Fake\n\n C...
# 3  Source:El Nuevo Siglo\n\n Prediction:Fake\n\n ...
# 4  Source:El Mundo\n\n Prediction:True\n\n Conten...
#
#                                                Title         Type  \
# 0                                                           Tweet
# 1                                                           Tweet
# 2  Ben Simmons da ‘su verdad’ sobre su salida de ...  Web Article
# 3  Destacan habilidades profesionales de perfiles...  Web Article
# 4  Subcomisión avaló las 75 candidaturas a la C...  Web Article
#
#    __index_level_0__
# 0                140
# 1                164
# 2               1449
# 3                 29
# 4                 65

# %%
train.isnull().sum()
# Out:
# Annotation_action              0
# Article_ID                     0
# Author                      2781
# Content                        0
# Corrected_label                0
# Date_posted                  552
# Link                        1350
# Prediction                     0
# Prediction_prob                0
# Preprocessed_text              0
# Rescaled_prediction_prob       0
# Source                         0
# Text                           0
# Title                          0
# Type                           0
# __index_level_0__              0
# dtype: int64

# %%
train.head()
# Out:
#   Annotation_action  Article_ID Author  \
# 0    Don't Annotate        2858   None
# 1    Don't Annotate        2005   None
# 2          Annotate         453   None
# 3    Don't Annotate         590   None
# 4    Don't Annotate        1008   None
#
#                                              Content Corrected_label  \
# 0  En un artículo difundido en su sitio personal ...            Fake
# 1  🔴 El líder nacional de Morena, @mario_delgado ...            True
# 2  NUEVA YORK.- Ben Simmons aseguró el martes qu...            Fake
# 3  Un estudio realizado por la empresa tecnológi...            True
# 4  \nLa Subcomisión Política leyó ayer públic...            True
#
#   Date_posted                                               Link Prediction  \
# 0  2022-03-01                                               None       Fake
# 1  2022-01-19                                               None       True
# 2        None  https://vanguardia.com.mx/deportes/ben-simmons...       Fake
# 3        None  http://www.elnuevosiglo.com.co/articulos/02-14...       Fake
# 4  2020-07-28  https://diario.elmundo.sv/Política/subcomision...       True
#
#    Prediction_prob                                  Preprocessed_text  \
# 0         0.632735  artículo difundido sitio personal coordinador...
# 1         0.441359  líder nacional Morena @mario_delgado llamar I...
# 2         0.564037  YORK.- Ben Simmons martes problema mental inic...
# 3         0.584732  estudio empresa tecnológico gamificación Nawai...
# 4         0.357733  Subcomisión Política leer públicamente informe...
#
#    Rescaled_prediction_prob          Source  \
# 0                  0.132735         proceso
# 1                  0.058641       Excelsior
# 2                  0.064037   La Vanguardia
# 3                  0.084732  El Nuevo Siglo
# 4                  0.142267        El Mundo
#
#                                                 Text  \
# 0  Source:proceso\n\n Prediction:Fake\n\n Content...
# 1  Source:Excelsior\n\n Prediction:True\n\n Conte...
# 2  Source:La Vanguardia\n\n Prediction:Fake\n\n C...
# 3  Source:El Nuevo Siglo\n\n Prediction:Fake\n\n ...
# 4  Source:El Mundo\n\n Prediction:True\n\n Conten...
#
#                                                Title         Type  \
# 0                                                           Tweet
# 1                                                           Tweet
# 2  Ben Simmons da ‘su verdad’ sobre su salida de ...  Web Article
# 3  Destacan habilidades profesionales de perfiles...  Web Article
# 4  Subcomisión avaló las 75 candidaturas a la C...  Web Article
#
#    __index_level_0__
# 0                140
# 1                164
# 2               1449
# 3                 29
# 4                 65

# %%
train = train.drop(['Date_posted'], axis=1)

# %%
train.head()
# Out:
#   Annotation_action  Article_ID Author  \
# 0    Don't Annotate        2858   None
# 1    Don't Annotate        2005   None
# 2          Annotate         453   None
# 3    Don't Annotate         590   None
# 4    Don't Annotate        1008   None
#
#                                              Content Corrected_label  \
# 0  En un artículo difundido en su sitio personal ...            Fake
# 1  🔴 El líder nacional de Morena, @mario_delgado ...            True
# 2  NUEVA YORK.- Ben Simmons aseguró el martes qu...            Fake
# 3  Un estudio realizado por la empresa tecnológi...            True
# 4  \nLa Subcomisión Política leyó ayer públic...            True
#
#                                                 Link Prediction  \
# 0                                               None       Fake
# 1                                               None       True
# 2  https://vanguardia.com.mx/deportes/ben-simmons...       Fake
# 3  http://www.elnuevosiglo.com.co/articulos/02-14...       Fake
# 4  https://diario.elmundo.sv/Política/subcomision...       True
#
#    Prediction_prob                                  Preprocessed_text  \
# 0         0.632735  artículo difundido sitio personal coordinador...
# 1         0.441359  líder nacional Morena @mario_delgado llamar I...
# 2         0.564037  YORK.- Ben Simmons martes problema mental inic...
# 3         0.584732  estudio empresa tecnológico gamificación Nawai...
# 4         0.357733  Subcomisión Política leer públicamente informe...
#
#    Rescaled_prediction_prob          Source  \
# 0                  0.132735         proceso
# 1                  0.058641       Excelsior
# 2                  0.064037   La Vanguardia
# 3                  0.084732  El Nuevo Siglo
# 4                  0.142267        El Mundo
#
#                                                 Text  \
# 0  Source:proceso\n\n Prediction:Fake\n\n Content...
# 1  Source:Excelsior\n\n Prediction:True\n\n Conte...
# 2  Source:La Vanguardia\n\n Prediction:Fake\n\n C...
# 3  Source:El Nuevo Siglo\n\n Prediction:Fake\n\n ...
# 4  Source:El Mundo\n\n Prediction:True\n\n Conten...
#
#                                                Title         Type  \
# 0                                                           Tweet
# 1                                                           Tweet
# 2  Ben Simmons da ‘su verdad’ sobre su salida de ...  Web Article
# 3  Destacan habilidades profesionales de perfiles...  Web Article
# 4  Subcomisión avaló las 75 candidaturas a la C...  Web Article
#
#    __index_level_0__
# 0                140
# 1                164
# 2               1449
# 3                 29
# 4                 65

# %%
from pycaret.nlp import *

# %%
#Grabs topics from the dataset and classifies using LDA
df = get_topics(data=train, text='Text')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d368b_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d368b_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_d368b_row0_col1" class="data row0 col1" >2113</td>
#     </tr>
#     <tr>
#       <td id="T_d368b_row1_col0" class="data row1 col0" >Documents</td>
#       <td id="T_d368b_row1_col1" class="data row1 col1" >2782</td>
#     </tr>
#     <tr>
#       <td id="T_d368b_row2_col0" class="data row2 col0" >Vocab Size</td>
#       <td id="T_d368b_row2_col1" class="data row2 col1" >4046</td>
#     </tr>
#     <tr>
#       <td id="T_d368b_row3_col0" class="data row3 col0" >Custom Stopwords</td>
#       <td id="T_d368b_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
ml = create_model(model='lda', multi_core=True)

# %%
#assigns lda to dataset and preps for nlp classification
lda_model = assign_model(ml)

# %%
lda_model.head()
# Out:
#   Annotation_action  Article_ID Author  \
# 0    Don't Annotate        2858   None
# 1    Don't Annotate        2005   None
# 2          Annotate         453   None
# 3    Don't Annotate         590   None
# 4    Don't Annotate        1008   None
#
#                                              Content Corrected_label  \
# 0  En un artículo difundido en su sitio personal ...            Fake
# 1  🔴 El líder nacional de Morena, @mario_delgado ...            True
# 2  NUEVA YORK.- Ben Simmons aseguró el martes qu...            Fake
# 3  Un estudio realizado por la empresa tecnológi...            True
# 4  \nLa Subcomisión Política leyó ayer públic...            True
#
#                                                 Link Prediction  \
# 0                                               None       Fake
# 1                                               None       True
# 2  https://vanguardia.com.mx/deportes/ben-simmons...       Fake
# 3  http://www.elnuevosiglo.com.co/articulos/02-14...       Fake
# 4  https://diario.elmundo.sv/Política/subcomision...       True
#
#    Prediction_prob                                  Preprocessed_text  \
# 0         0.632735  artículo difundido sitio personal coordinador...
# 1         0.441359  líder nacional Morena @mario_delgado llamar I...
# 2         0.564037  YORK.- Ben Simmons martes problema mental inic...
# 3         0.584732  estudio empresa tecnológico gamificación Nawai...
# 4         0.357733  Subcomisión Política leer públicamente informe...
#
#    Rescaled_prediction_prob  ...  \
# 0                  0.132735  ...
# 1                  0.058641  ...
# 2                  0.064037  ...
# 3                  0.084732  ...
# 4                  0.142267  ...
#
#                                                 Text  \
# 0                source prediction fake content pone
# 1                     source prediction true content
# 2                                   ante creia draft
# 3  source fake perfile senior mayore adaptarse si...
# 4  true son expediente como tre propietario suple...
#
#                                                Title         Type  \
# 0                                                           Tweet
# 1                                                           Tweet
# 2  Ben Simmons da ‘su verdad’ sobre su salida de ...  Web Article
# 3  Destacan habilidades profesionales de perfiles...  Web Article
# 4  Subcomisión avaló las 75 candidaturas a la C...  Web Article
#
#   __index_level_0__   Topic_0   Topic_1   Topic_2   Topic_3  Dominant_Topic  \
# 0               140  0.706484  0.041770  0.209314  0.042432         Topic 0
# 1               164  0.848370  0.050423  0.050542  0.050665         Topic 0
# 2              1449  0.062965  0.065865  0.808570  0.062600         Topic 2
# 3                29  0.684642  0.033528  0.031479  0.250351         Topic 0
# 4                65  0.007660  0.124200  0.696412  0.171729         Topic 2
#
#   Perc_Dominant_Topic
# 0                0.71
# 1                0.85
# 2                0.81
# 3                0.68
# 4                0.70
#
# [5 rows x 21 columns]

# %%
#Evaluates all important metrics
evaluate_model(ml)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Frequency Plot', 'freque…

# %%
#Fits model to the dataset and target
lda_model_1 = lda_model[['Corrected_label', 'Topic_0', 'Topic_1', 'Topic_2', 'Topic_3']]

# %%
lda_model_1
# Out:
#      Corrected_label   Topic_0   Topic_1   Topic_2   Topic_3
# 0               Fake  0.706484  0.041770  0.209314  0.042432
# 1               True  0.848370  0.050423  0.050542  0.050665
# 2               Fake  0.062965  0.065865  0.808570  0.062600
# 3               True  0.684642  0.033528  0.031479  0.250351
# 4               True  0.007660  0.124200  0.696412  0.171729
# ...              ...       ...       ...       ...       ...
# 2777            Fake  0.705586  0.043361  0.044824  0.206229
# 2778            True  0.042735  0.042461  0.871825  0.042979
# 2779            Fake  0.811136  0.062760  0.063075  0.063030
# 2780            True  0.614677  0.037808  0.310963  0.036551
# 2781            Fake  0.902339  0.033861  0.032423  0.031377
#
# [2782 rows x 5 columns]

# %%
# !pip install tornado --quiet

# %%
from pycaret.classification import *

# %%
#Sets up classification model
cla = setup(data = lda_model_1, target='Corrected_label', session_id=123, train_size=0.80, log_experiment = True, experiment_name='nlp')
# Out:
#                                Description             Value
# 0                               session_id               123
# 1                                   Target   Corrected_label
# 2                              Target Type            Binary
# 3                            Label Encoded  Fake: 0, True: 1
# 4                            Original Data         (2782, 5)
# 5                           Missing Values             False
# 6                         Numeric Features                 4
# 7                     Categorical Features                 0
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (2225, 4)
# 12                    Transformed Test Set          (557, 4)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU             False
# 19                          Log Experiment              True
# 20                         Experiment Name               nlp
# 21                                     USI              0207
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize             False
# 30                        Normalize Method              None
# 31                          Transformation             False
# 32                   Transformation Method              None
# 33                                     PCA             False
# 34                              PCA Method              None
# 35                          PCA Components              None
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44             Remove Perfect Collinearity              True
# 45                              Clustering             False
# 46                    Clustering Iteration              None
# 47                     Polynomial Features             False
# 48                       Polynomial Degree              None
# 49                    Trignometry Features             False
# 50                    Polynomial Threshold              None
# 51                          Group Features             False
# 52                       Feature Selection             False
# 53                Feature Selection Method           classic
# 54            Features Selection Threshold              None
# 55                     Feature Interaction             False
# 56                           Feature Ratio             False
# 57                   Interaction Threshold              None
# 58                           Fix Imbalance             False
# 59                    Fix Imbalance Method             SMOTE
# 2022/04/08 11:39:04 INFO mlflow.tracking.fluent: Experiment with name 'nlp' does not exist. Creating a new experiment.

# %%
#Previews best models based on dataset metrics
best = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# gbc          Gradient Boosting Classifier    0.6894  0.6882  0.9040  0.7113
# catboost              CatBoost Classifier    0.6885  0.6928  0.8839  0.7167
# knn                K Neighbors Classifier    0.6760  0.6503  0.8174  0.7307
# xgboost         Extreme Gradient Boosting    0.6742  0.7082  0.8067  0.7335
# lightgbm  Light Gradient Boosting Machine    0.6701  0.6993  0.8114  0.7273
# lr                    Logistic Regression    0.6697  0.5357  1.0000  0.6697
# svm                   SVM - Linear Kernel    0.6697  0.0000  1.0000  0.6697
# ridge                    Ridge Classifier    0.6697  0.0000  1.0000  0.6697
# lda          Linear Discriminant Analysis    0.6697  0.5355  1.0000  0.6697
# dummy                    Dummy Classifier    0.6697  0.5000  1.0000  0.6697
# rf               Random Forest Classifier    0.6683  0.6941  0.8040  0.7283
# qda       Quadratic Discriminant Analysis    0.6670  0.5217  0.9953  0.6689
# et                 Extra Trees Classifier    0.6629  0.6775  0.7698  0.7374
# nb                            Naive Bayes    0.6620  0.5368  0.9846  0.6680
# ada                  Ada Boost Classifier    0.6602  0.6298  0.9638  0.6718
# dt               Decision Tree Classifier    0.6391  0.6038  0.7134  0.7390
#
#               F1   Kappa     MCC  TT (Sec)
# gbc       0.7960  0.1826  0.2070     0.528
# catboost  0.7915  0.2009  0.2213     4.264
# knn       0.7714  0.2203  0.2251     0.152
# xgboost   0.7678  0.2241  0.2287     4.529
# lightgbm  0.7666  0.2082  0.2139     0.285
# lr        0.8022  0.0000  0.0000     0.818
# svm       0.8022  0.0000  0.0000     0.029
# ridge     0.8022  0.0000  0.0000     0.031
# lda       0.8022  0.0000  0.0000     0.038
# dummy     0.8022  0.0000  0.0000     0.022
# rf        0.7639  0.2096  0.2146     0.979
# qda       0.8001 -0.0044 -0.0156     0.032
# et        0.7528  0.2226  0.2246     0.676
# nb        0.7958 -0.0093 -0.0197     0.028
# ada       0.7916  0.0107  0.0107     0.347
# dt        0.7252  0.1984  0.1993     0.047

# %%
#Models for dataset regression including random forest, lightgbm, extra trees, linear discriminant analysis, and gradient boost along with accuracy scores, auc, recall, precision, F1 scores, Kappa, and MCC scores
cla_rf = create_model('rf')
cla_lgbm = create_model('lightgbm')
cla_et = create_model('et')
cla_gbc = create_model('gbc')
cla_lda = create_model('lda')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1  Kappa  MCC
# Fold
# 0       0.6682  0.5325     1.0  0.6682  0.8011    0.0  0.0
# 1       0.6682  0.5658     1.0  0.6682  0.8011    0.0  0.0
# 2       0.6682  0.5662     1.0  0.6682  0.8011    0.0  0.0
# 3       0.6682  0.5273     1.0  0.6682  0.8011    0.0  0.0
# 4       0.6682  0.5583     1.0  0.6682  0.8011    0.0  0.0
# 5       0.6712  0.5052     1.0  0.6712  0.8032    0.0  0.0
# 6       0.6712  0.4922     1.0  0.6712  0.8032    0.0  0.0
# 7       0.6712  0.5462     1.0  0.6712  0.8032    0.0  0.0
# 8       0.6712  0.5462     1.0  0.6712  0.8032    0.0  0.0
# 9       0.6712  0.5152     1.0  0.6712  0.8032    0.0  0.0
# Mean    0.6697  0.5355     1.0  0.6697  0.8022    0.0  0.0
# Std     0.0015  0.0243     0.0  0.0015  0.0011    0.0  0.0

# %%
#Tuned models with metrics
tuned_cla_rf = tune_model(cla_rf)
tuned_cla_lgbm = tune_model(cla_lgbm)
tuned_cla_et = tune_model(cla_et)
tuned_cla_gbc = tune_model(cla_gbc)
tuned_cla_lda = tune_model(cla_lda)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1  Kappa  MCC
# Fold
# 0       0.6682  0.5283     1.0  0.6682  0.8011    0.0  0.0
# 1       0.6682  0.5785     1.0  0.6682  0.8011    0.0  0.0
# 2       0.6682  0.5595     1.0  0.6682  0.8011    0.0  0.0
# 3       0.6682  0.5216     1.0  0.6682  0.8011    0.0  0.0
# 4       0.6682  0.5412     1.0  0.6682  0.8011    0.0  0.0
# 5       0.6712  0.5298     1.0  0.6712  0.8032    0.0  0.0
# 6       0.6712  0.4899     1.0  0.6712  0.8032    0.0  0.0
# 7       0.6712  0.5421     1.0  0.6712  0.8032    0.0  0.0
# 8       0.6712  0.5371     1.0  0.6712  0.8032    0.0  0.0
# 9       0.6712  0.5338     1.0  0.6712  0.8032    0.0  0.0
# Mean    0.6697  0.5362     1.0  0.6697  0.8022    0.0  0.0
# Std     0.0015  0.0220     0.0  0.0015  0.0011    0.0  0.0

# %%
#This cell and the next four cells provide accuracy metrics of the tuned models starting with random forest, then lightgbm, then extra trees, gradient boost and finally lda
#evaluate_model(tuned_cla_rf)
#evaluate_model(tuned_cla_lgbm)
#evaluate_model(tuned_cla_et)
#evaluate_model(tuned_cla_gbc)
#evaluate_model(tuned_cla_lda)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
evaluate_model(tuned_cla_lda)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
#Installs Explainer Dashboard or visual analysis
# !pip install explainerdashboard
# Out:
# Requirement already satisfied: explainerdashboard in /usr/local/lib/python3.7/dist-packages (0.3.8.2)
# Requirement already satisfied: dash-auth in /usr/local/lib/python3.7/dist-packages (from explainerdashboard) (1.4.1)
# Requirement already satisfied: waitress in /usr/local/lib/python3.7/dist-packages (from explainerdashboard) (2.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from explainerdashboard) (1.21.5)
# Requirement already satisfied: dash-bootstrap-components<1 in /usr/local/lib/python3.7/dist-packages (from explainerdashboard) (0.13.1)
# Requirement already satisfied: jupyter-dash in /usr/local/lib/python3.7/dist-packages (from explainerdashboard) (0.4.2)
# Requirement already satisfied: dtreeviz>=1.3 in /usr/local/lib/python3.7/dist-packages (from explainerdashboard) (1.3.5)
# Requirement already satisfied: shap>=0.37 in /usr/local/lib/python3.7/dist-packages (from explainerdashboard) (0.40.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from explainerdashboard) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from explainerdashboard) (1.0.1)
# Requirement already satisfied: flask-simplelogin in /usr/local/lib/python3.7/dist-packages (from explainerdashboard) (0.0.7)
# Requirement already satisfied: graphviz>=0.18.2 in /usr/local/lib/python3.7/dist-packages (from explainerdashboard) (0.19.1)
# Requirement already satisfied: oyaml in /usr/local/lib/python3.7/dist-packages (from explainerdashboard) (1.0)
# Requirement already satisfied: dash>=2 in /usr/local/lib/python3.7/dist-packages (from explainerdashboard) (2.3.1)
# Requirement already satisfied: Werkzeug<=2.0.3 in /usr/local/lib/python3.7/dist-packages (from explainerdashboard) (1.0.1)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.7/dist-packages (from explainerdashboard) (1.3.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from explainerdashboard) (0.23.2)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.7/dist-packages (from dash>=2->explainerdashboard) (5.0.0)
# Requirement already satisfied: Flask>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from dash>=2->explainerdashboard) (1.1.4)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from dash>=2->explainerdashboard) (5.5.0)
# Requirement already satisfied: flask-compress in /usr/local/lib/python3.7/dist-packages (from dash>=2->explainerdashboard) (1.11)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.7/dist-packages (from dash>=2->explainerdashboard) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.7/dist-packages (from dash>=2->explainerdashboard) (2.0.0)
# Requirement already satisfied: colour in /usr/local/lib/python3.7/dist-packages (from dtreeviz>=1.3->explainerdashboard) (0.1.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from dtreeviz>=1.3->explainerdashboard) (3.5.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from dtreeviz>=1.3->explainerdashboard) (3.6.4)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash>=2->explainerdashboard) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash>=2->explainerdashboard) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=1.0.4->dash>=2->explainerdashboard) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1->explainerdashboard) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1->explainerdashboard) (2018.9)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=5.0.0->dash>=2->explainerdashboard) (8.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly>=5.0.0->dash>=2->explainerdashboard) (1.15.0)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.7/dist-packages (from shap>=0.37->explainerdashboard) (21.3)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.7/dist-packages (from shap>=0.37->explainerdashboard) (0.0.7)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.7/dist-packages (from shap>=0.37->explainerdashboard) (4.63.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from shap>=0.37->explainerdashboard) (1.3.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap>=0.37->explainerdashboard) (0.51.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from shap>=0.37->explainerdashboard) (1.5.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>20.9->shap>=0.37->explainerdashboard) (3.0.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from dash-auth->explainerdashboard) (2.27.1)
# Requirement already satisfied: ua-parser in /usr/local/lib/python3.7/dist-packages (from dash-auth->explainerdashboard) (0.10.0)
# Requirement already satisfied: retrying in /usr/local/lib/python3.7/dist-packages (from dash-auth->explainerdashboard) (1.3.3)
# Requirement already satisfied: flask-seasurf in /usr/local/lib/python3.7/dist-packages (from dash-auth->explainerdashboard) (1.1.1)
# Requirement already satisfied: chart-studio>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from dash-auth->explainerdashboard) (1.1.0)
# Requirement already satisfied: brotli in /usr/local/lib/python3.7/dist-packages (from flask-compress->dash>=2->explainerdashboard) (1.0.9)
# Requirement already satisfied: flask_wtf in /usr/local/lib/python3.7/dist-packages (from flask-simplelogin->explainerdashboard) (1.0.1)
# Requirement already satisfied: WTForms in /usr/local/lib/python3.7/dist-packages (from flask_wtf->flask-simplelogin->explainerdashboard) (3.0.1)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.7/dist-packages (from jupyter-dash->explainerdashboard) (1.7.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.7/dist-packages (from jupyter-dash->explainerdashboard) (1.5.4)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.7/dist-packages (from jupyter-dash->explainerdashboard) (6.12.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from jupyter-dash->explainerdashboard) (7.32.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from ansi2html->jupyter-dash->explainerdashboard) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->ansi2html->jupyter-dash->explainerdashboard) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->ansi2html->jupyter-dash->explainerdashboard) (4.1.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.7/dist-packages (from ipykernel->jupyter-dash->explainerdashboard) (7.2.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.7/dist-packages (from ipykernel->jupyter-dash->explainerdashboard) (0.1.3)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel->jupyter-dash->explainerdashboard) (5.1.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from ipykernel->jupyter-dash->explainerdashboard) (5.9.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel->jupyter-dash->explainerdashboard) (1.0.0)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.7/dist-packages (from ipykernel->jupyter-dash->explainerdashboard) (6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash->explainerdashboard) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash->explainerdashboard) (3.0.29)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash->explainerdashboard) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash->explainerdashboard) (57.4.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash->explainerdashboard) (0.18.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash->explainerdashboard) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash->explainerdashboard) (4.4.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-dash->explainerdashboard) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython->jupyter-dash->explainerdashboard) (0.8.3)
# Requirement already satisfied: pyzmq>=22.3 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash->explainerdashboard) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash->explainerdashboard) (4.9.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash->explainerdashboard) (0.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3->ipython->jupyter-dash->explainerdashboard) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash->explainerdashboard) (0.2.5)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (4.31.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (1.4.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (7.1.2)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba->shap>=0.37->explainerdashboard) (0.34.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from oyaml->explainerdashboard) (5.4.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (21.4.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (8.12.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (1.11.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (0.7.1)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (1.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->dash-auth->explainerdashboard) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->dash-auth->explainerdashboard) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests->dash-auth->explainerdashboard) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->dash-auth->explainerdashboard) (2021.10.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->explainerdashboard) (3.1.0)

# %%
test = pd.read_parquet("/content/df1dafd7a13176813587af8ca6367f723827be4a93522907e443925340f4e445")

# %%
test.head()
# Out:
#   Annotation_action  Article_ID Author  \
# 0    Don't Annotate         636   None
# 1    Don't Annotate         536   None
# 2    Don't Annotate        2184   None
# 3    Don't Annotate        2914   None
# 4          Annotate         261   None
#
#                                              Content Corrected_label  \
# 0  \n\n\r\nMalcolm Cartagena, capacitador del Tri...            True
# 1  \n\n\r\nLa Comisión Especial Electoral del FM...            True
# 2  Tras el el enfrentamiento entre simpatizantes ...            True
# 3  La @Coparmex advirtió que a la @CFEmx le urge ...            Fake
# 4  \nMichelle Sol, alcaldesa de Nuevo Cuscatlán....            True
#
#   Date_posted                                               Link Prediction  \
# 0  2017-12-30  https://diario.elmundo.sv/Política/resuelve-tu...       True
# 1  2019-06-21  https://diario.elmundo.sv/Política/cce-declara...       Fake
# 2  2018-04-01                                               None       Fake
# 3  2021-12-10                                               None       Fake
# 4  2019-05-10  https://diario.elmundo.sv/Política/michelle-so...       True
#
#    Prediction_prob                                  Preprocessed_text  \
# 0         0.410082  Malcolm Cartagena capacitador Tribunal Supremo...
# 1         0.575066  Comisión Especial Electoral FMLN declarar maña...
# 2         0.564037  enfrentamiento simpatizante PRD Morena previo ...
# 3         0.649744  @coparmex advertir @cfemx urge reestructura fi...
# 4         0.462732  Michelle Sol alcaldesa Cuscatlán alcaldesa Cus...
#
#    Rescaled_prediction_prob        Source  \
# 0                  0.089918      El Mundo
# 1                  0.075066      El Mundo
# 2                  0.064037  SinEmbargoMX
# 3                  0.149744       proceso
# 4                  0.037268      El Mundo
#
#                                                 Text  \
# 0  Source:El Mundo\n\n Prediction:True\n\n Conten...
# 1  Source:El Mundo\n\n Prediction:Fake\n\n Conten...
# 2  Source:SinEmbargoMX\n\n Prediction:Fake\n\n Co...
# 3  Source:proceso\n\n Prediction:Fake\n\n Content...
# 4  Source:El Mundo\n\n Prediction:True\n\n Conten...
#
#                                                Title         Type  \
# 0   Resuelve tus dudas sobre las JRV en 12 preguntas  Web Article
# 1  CEE declara a Ortiz como nuevo secretario gene...  Web Article
# 2                                                           Tweet
# 3                                                           Tweet
# 4  Michelle Sol depondrá cargo en alcaldía tras...  Web Article
#
#    __index_level_0__
# 0               1593
# 1               1486
# 2                532
# 3               1153
# 4                132

# %%
test_df = get_topics(data=test, text='Text')
# Out:
# <style type="text/css">
# </style>
# <table id="T_a048d_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a048d_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_a048d_row0_col1" class="data row0 col1" >1783</td>
#     </tr>
#     <tr>
#       <td id="T_a048d_row1_col0" class="data row1 col0" >Documents</td>
#       <td id="T_a048d_row1_col1" class="data row1 col1" >310</td>
#     </tr>
#     <tr>
#       <td id="T_a048d_row2_col0" class="data row2 col0" >Vocab Size</td>
#       <td id="T_a048d_row2_col1" class="data row2 col1" >1171</td>
#     </tr>
#     <tr>
#       <td id="T_a048d_row3_col0" class="data row3 col0" >Custom Stopwords</td>
#       <td id="T_a048d_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
stacker = stack_models([tuned_cla_rf, tuned_cla_lda, tuned_cla_lgbm, tuned_cla_et, tuned_cla_gbc])
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.6682  0.7109  0.8523  0.7095  0.7744  0.1666  0.1771
# 1       0.7040  0.7283  0.8993  0.7243  0.8024  0.2395  0.2632
# 2       0.7175  0.7495  0.9060  0.7337  0.8108  0.2768  0.3023
# 3       0.7175  0.7228  0.8926  0.7389  0.8085  0.2878  0.3073
# 4       0.6771  0.6680  0.8725  0.7104  0.7831  0.1767  0.1918
# 5       0.7252  0.7684  0.9530  0.7245  0.8232  0.2552  0.3116
# 6       0.6667  0.6613  0.8792  0.7005  0.7798  0.1292  0.1445
# 7       0.6982  0.7217  0.8926  0.7228  0.7988  0.2210  0.2420
# 8       0.7162  0.7099  0.9128  0.7312  0.8119  0.2616  0.2904
# 9       0.6351  0.6297  0.8389  0.6868  0.7553  0.0657  0.0710
# Mean    0.6926  0.7070  0.8899  0.7183  0.7948  0.2080  0.2301
# Std     0.0280  0.0401  0.0305  0.0154  0.0199  0.0682  0.0772

# %%
test_df.head()
# Out:
#   Annotation_action  Article_ID Author  \
# 0    Don't Annotate         636   None
# 1    Don't Annotate         536   None
# 2    Don't Annotate        2184   None
# 3    Don't Annotate        2914   None
# 4          Annotate         261   None
#
#                                              Content Corrected_label  \
# 0  \n\n\r\nMalcolm Cartagena, capacitador del Tri...            True
# 1  \n\n\r\nLa Comisión Especial Electoral del FM...            True
# 2  Tras el el enfrentamiento entre simpatizantes ...            True
# 3  La @Coparmex advirtió que a la @CFEmx le urge ...            Fake
# 4  \nMichelle Sol, alcaldesa de Nuevo Cuscatlán....            True
#
#   Date_posted                                               Link Prediction  \
# 0  2017-12-30  https://diario.elmundo.sv/Política/resuelve-tu...       True
# 1  2019-06-21  https://diario.elmundo.sv/Política/cce-declara...       Fake
# 2  2018-04-01                                               None       Fake
# 3  2021-12-10                                               None       Fake
# 4  2019-05-10  https://diario.elmundo.sv/Política/michelle-so...       True
#
#    Prediction_prob                                  Preprocessed_text  ...  \
# 0         0.410082  Malcolm Cartagena capacitador Tribunal Supremo...  ...
# 1         0.575066  Comisión Especial Electoral FMLN declarar maña...  ...
# 2         0.564037  enfrentamiento simpatizante PRD Morena previo ...  ...
# 3         0.649744  @coparmex advertir @cfemx urge reestructura fi...  ...
# 4         0.462732  Michelle Sol alcaldesa Cuscatlán alcaldesa Cus...  ...
#
#                                                 Text  \
# 0  tse resuelve afiliada nacional votacion normal...
# 1  izquierda cargo principal aristide cargo ese c...
# 2                   simpatizante eyrgbkbph cqqcnqebp
# 3                                    source oldstgud
# 4        tra semana municipal funcione ella gabinete
#
#                                                Title         Type  \
# 0   Resuelve tus dudas sobre las JRV en 12 preguntas  Web Article
# 1  CEE declara a Ortiz como nuevo secretario gene...  Web Article
# 2                                                           Tweet
# 3                                                           Tweet
# 4  Michelle Sol depondrá cargo en alcaldía tras...  Web Article
#
#   __index_level_0__   Topic_0   Topic_1   Topic_2   Topic_3  Dominant_Topic  \
# 0              1593  0.993816  0.001543  0.001681  0.002960         Topic 0
# 1              1486  0.004734  0.005745  0.978507  0.011014         Topic 2
# 2               532  0.021306  0.025857  0.028160  0.924676         Topic 3
# 3              1153  0.030082  0.036507  0.039759  0.893652         Topic 3
# 4               132  0.944766  0.013789  0.015017  0.026428         Topic 0
#
#    Perc_Dominant_Topic
# 0                 0.99
# 1                 0.98
# 2                 0.92
# 3                 0.89
# 4                 0.94
#
# [5 rows x 22 columns]

# %%
test_df_model = test_df[['Prediction', 'Topic_0', 'Topic_1', 'Topic_2', 'Topic_3']]

# %%
#Provides predictions based on a tuned stacked model
predictions = predict_model(stacker, data=test_df_model, raw_score=True)
predictions.head()
# Out:
#   Prediction   Topic_0   Topic_1   Topic_2   Topic_3 Label  Score_Fake  \
# 0       True  0.993816  0.001543  0.001681  0.002960  Fake      0.5083
# 1       Fake  0.004734  0.005745  0.978507  0.011014  True      0.1829
# 2       Fake  0.021306  0.025857  0.028160  0.924676  True      0.2060
# 3       Fake  0.030082  0.036507  0.039759  0.893652  True      0.3128
# 4       True  0.944766  0.013789  0.015017  0.026428  Fake      0.5679
#
#    Score_True
# 0      0.4917
# 1      0.8171
# 2      0.7940
# 3      0.6872
# 4      0.4321

# %%
#creates a model dashboard for the stacked models
dashboard(stacker, display_format='inline')
# Out:
# WARNING: Parameter shap='guess', but failed to guess the type of shap explainer to use for StackingClassifier. Defaulting to the model agnostic shap.KernelExplainer (shap='kernel'). However this will be slow, so if your model is compatible with e.g. shap.TreeExplainer or shap.LinearExplainer then pass shap='tree' or shap='linear'!
# WARNING: For shap='kernel', shap interaction values can unfortunately not be calculated!
# Note: shap values for shap='kernel' normally get calculated against X_background, but paramater X_background=None, so setting X_background=shap.sample(X, 50)...
# Generating self.shap_explainer = shap.KernelExplainer(model, X, link='identity')
# Building ExplainerDashboard..
# For this type of model and model_output interactions don't work, so setting shap_interaction=False...
# The explainer object has no decision_trees property. so setting decision_trees=False...
# Generating layout...
# Calculating shap values...
#   0%|          | 0/557 [00:00<?, ?it/s]
# Calculating prediction probabilities...
# Calculating metrics...
# Calculating confusion matrices...
# Calculating classification_dfs...
# Calculating roc auc curves...
# Calculating pr auc curves...
# Calculating liftcurve_dfs...
# Calculating dependencies...
# Calculating permutation importances (if slow, try setting n_jobs parameter)...
# Calculating pred_percentiles...
# Calculating predictions...
# Reminder: you can store the explainer (including calculated dependencies) with explainer.dump('explainer.joblib') and reload with e.g. ClassifierExplainer.from_file('explainer.joblib')
# Registering callbacks...
# Starting ExplainerDashboard inline (terminate it with ExplainerDashboard.terminate(8050))

# %%
# !mlflow ui
# Out:
# [2022-04-08 11:53:35 +0000] [18799] [INFO] Starting gunicorn 20.1.0
# [2022-04-08 11:53:35 +0000] [18799] [INFO] Listening at: http://127.0.0.1:5000 (18799)
# [2022-04-08 11:53:35 +0000] [18799] [INFO] Using worker: sync
# [2022-04-08 11:53:35 +0000] [18803] [INFO] Booting worker with pid: 18803
#
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# [2022-04-08 17:15:29 +0000] [18799] [INFO] Handling signal: int
# [2022-04-08 17:15:29 +0000] [18803] [INFO] Worker exiting (pid: 18803)
#
# Aborted!
# [2022-04-08 17:15:30 +0000] [18799] [INFO] Shutting down: Master
