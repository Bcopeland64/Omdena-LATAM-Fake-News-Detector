# %%
# !pip3 install newspaper3k
import requests
import nltk
nltk.download('punkt')
from bs4 import BeautifulSoup
from newspaper import Article
import pandas as pd
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
feed = 'https://www.lavanguardia.com/rss/politica.xml'

response = requests.get(feed)

website = response.content

soup = BeautifulSoup(website, features='xml')

items = soup.find_all('item')

articles = []
for item in items:
    link = item.find('link').text
    articles.append(link)

# %%
from newspaper import Article

# %%
multi_pages = []
for url in articles:
    article = Article(url)
    article.download()
    article.parse()
    article.nlp()

    df = pd.DataFrame()
    titles = []
    links = []
    content_text =[]
    published_on = []

    title = article.title
    text = article.text
    keywords = article.keywords
    summary = article.summary
    date = article.publish_date
    authors = article.authors

    titles.append(title)
    links.append(url)
    content_text.append(summary)
    published_on.append(date)

        
    print('************************************************************')
    print(f"Title: {title}")
    print(f"URL: {url}")
    print(f"Authors: {authors}")
    print(f"Date: {date}")
    print(f"Keywords: {keywords}")
    print(f"Summary: {summary}")
    print(f"Text: {text}")
    print('************************************************************')

    df['title'] = titles
    df['link'] = links
    df['content_text'] = content_text
    df['published_on'] = published_on
    multi_pages.append(df)
 
df_new = pd.concat(multi_pages).reset_index(drop =True)
df_new.head()
# Out:
# URL: https://www.lavanguardia.com/politica/20220215/8058807/govern-lamenta-criticas-aragones-llamar-ayer-unidad-suman.html
# Authors: ['Rubén Moreno', 'Àlex Tort', 'Isabel Garcia Pagan']
# Date: 2022-02-15 13:30:58+00:00
# Keywords: ['tras', 'unidad', 'govern', 'lamenta', 'llamar', 'ha', 'el', 'que', 'en', 'las', 'la', 'los', 'suman', 'para', 'y', 'críticas', 'aragonès']
# Summary: Pere Aragonès no ha tenido un buen comienzo a la hora de recoser la unidad independentista.
# La portavoz del Govern, Patrícia Plaja, ha asegurado que el Ejecutivo catalán respeta sus opiniones, pero ha lamentado los reproches, ya que “no suman”.
# “Después de que el president hiciera un llamamiento a abandonar los reproches y el tacticismo las primeras reacciones no suman”, ha dicho concretamente Plaja.
# Por otro lado, el Govern ha rebatido Jordi Sànchez, que en una entrevista esta mañana en Catalunya Ràdio se ha mostrado sorprendido para la referencia de Pere Aragonès ayer sobre los indultos.
# ...

# %%
len(articles)
# Out:
# 100

# %%
df_new.shape
# Out:
# (100, 4)

# %%
df_new.to_csv('lavanguardia.csv', index = False)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=24c8dfa6-c0e9-4b84-90c4-b37d7d82c67d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
